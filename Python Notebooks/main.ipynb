# %%
import os
import time
import re
import nltk
from text_processing_api import process_files_text_api
from text_processing_local import process_files_text_local
from transformers import AutoTokenizer, AutoModelForCausalLM
from huggingface_hub import InferenceClient
from read_data import read_docx,read_ppt
from image_processing_api import process_files_image_api

# %%
def main():
    x=int(input("API/Local. For API press 1, for locally press 2.(Kindly read the Readme file to get more information): "))
    if(x==1):
        x=input("Kindly enter your hf token id: ")
        if(not x):

# %%
model_image="google/gemma-3-27b-it"
model_text="meta-llama/Llama-3.1-8B-Instruct"
path="/Users/admin/Desktop/Projects/scrammbled/animal.jpg"
path_text=[path]

# %%
process_files_image_api(path_text,client,model_image,model_text)
# Out:
# Processing animal.jpg |████████████████████████████████████████| 3/3 [100%] in 6.2s (0.49/s)
# File:animal.jpg. Processing done in 6.32
# [{'path': '/Users/admin/Desktop/Projects/scrammbled/animal.jpg',
#   'file_name': 'orca_breaching_deep_blue',
#   'folder_name': 'Marinelife'}]

# %%
model_name="meta-llama/Llama-3.1-8B-Instruct"

# %%
start=time.time()
tokenizer=AutoTokenizer.from_pretrained(model_name)
model=AutoModelForCausalLM.from_pretrained(model_name,device_map='auto')
end=time.time()
print(f"Time Taken to load model:{end-start:.2f}s")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 start=time.time()
# ----> 2 tokenizer=AutoTokenizer.from_pretrained(model_name)
#       3 model=AutoModelForCausalLM.from_pretrained(model_name,device_map='auto')
#       4 end=time.time()
#
# NameError: name 'model_name' is not defined

# %%
client = InferenceClient(
    provider="nebius",
    token="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",
)

# %%
path="/Users/admin/Desktop/Projects/scrammbled/go_bruin.pptx"
text=read_ppt(path)
path_text=[(path,text)]

# %%
print(path_text)
# Out:
# [('/Users/admin/Desktop/Projects/scrammbled/go_bruin.pptx', '\nData Visualization \n\n\n\n[Source: Rocketry Today, 2021]\n\x0b\nRocket Launch Compare By Company\nWhat Americans think about economic trends？\n44% Americans think the economy is shrinking, 21% American think the economy is Staying the same, 20% American think the economy is Growing and 15% American is not sure.\nIn conclusion, most of American think the economic trend of the US is Shrinking.\nAir Bags will Reduce automobile fatalities\nWithout Airbag\nWith Airbag\nair bags will decrease in automobile fatalities\n\n\n\nCO Emissions\n[Source: UC Riverside Marlan and Rosemary Bourns College of Engineering]\nThe United States Global share has increased since 2011\n[Sources: World Population Review (2022), energy.gov (2012)\n\x0b\nChanges in U.S. share of global oil production over a decade(2011 to 2021).\n\nIncrease from 11% to 13%.\nThank you')]

# %%
# locally
process_files_text_local(path_text,tokenizer,model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # locally
# ----> 2 process_files_text_local(path_text,tokenizer,model)
#
# NameError: name 'tokenizer' is not defined

# %%
# api
process_files_text_api(path_text,client,model_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # api
# ----> 2 process_files_text_api(path_text,client,model_name)
#
# NameError: name 'client' is not defined

# %%
from huggingface_hub import InferenceClient

client = InferenceClient(token="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")
tokenizer=AutoTokeniser(model="google/gemma-3-21B-Instruct")
model_text=AutoModelFor
out = client.chat_completion(
    model="HuggingFaceH4/zephyr-7b-beta",
    messages=[{"role": "user", "content": "Hello"}]
)

print(out.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 5
#       1 from huggingface_hub import InferenceClient
#       3 client = InferenceClient(token="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")
# ----> 5 out = client.chat_completion(
#       6     model="HuggingFaceH4/zephyr-7b-beta",
#       7     messages=[{"role": "user", "content": "Hello"}]
#       8 )
#      10 print(out.choices[0].message.content)
#
# File ~/myenv/lib/python3.10/site-packages/huggingface_hub/inference/_client.py:924, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p, extra_body)
#     896 parameters = {
#     897     "model": payload_model,
#     898     "frequency_penalty": frequency_penalty,
# ...
