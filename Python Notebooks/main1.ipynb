# %%
import os
from huggingface_hub import InferenceClient
from text_processing_api import process_files_text_api
from read_data import collect_file_path,seperate_files,read_file
client = InferenceClient(
    provider="novita",
    api_key="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",
)

# %%
def main():
    path = "/Users/admin/Desktop/sample_data"

    model_name="meta-llama/Meta-Llama-3-8B-Instruct"
    # Collect file paths
    print("Accessing files......")
    all_files = collect_file_path(path)
    image_files, text_files = seperate_files(all_files)

    # Prepare text content
    path_text = [(file_path, read_file(file_path)) for file_path in text_files]
    print("Access files complete.....")
    # Process images and text
    print("Processing files.....")
    results = []
    results.append(process_files_text_api(path_text,client,model_name))
    print("Processing files complete....")
    print(f"""
    
    
    
    """)
    print(results)

# %%
main()
# Out:
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Accessing files......
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# CropBox missing from /Page, defaulting to MediaBox
# Access files complete.....
# Processing files.....
# on 1: <alive_progress.core.progress.__AliveBarHandle object at 0x14c4ada50>
# Processing 12222_777.docx |████████████████████████████████████████| 3/3 [100%] in 5.5s (0.55/s)
# File:12222_777.docx. Processing done in 5.49
# on 1: <alive_progress.core.progress.__AliveBarHandle object at 0x14c4a82e0>
# Processing paper_1col.pdf |████████████████████████████████████████| 3/3 [100%] in 5.6s (0.54/s)
# File:paper_1col.pdf. Processing done in 5.60
# on 1: <alive_progress.core.progress.__AliveBarHandle object at 0x14c4aeec0>
# Processing go_bruin.pptx |████████████████████████████████████████| 3/3 [100%] in 4.4s (0.68/s)
# File:go_bruin.pptx. Processing done in 4.40
# on 1: <alive_progress.core.progress.__AliveBarHandle object at 0x14c4aaf80>
# Processing 1111_63.csv |████████████████████████████████████████| 3/3 [100%] in 5.2s (0.58/s)
# File:1111_63.csv. Processing done in 5.19
# on 1: <alive_progress.core.progress.__AliveBarHandle object at 0x14c4aa4d0>
# Processing ccc.md |████████████████████████████████████████| 3/3 [100%] in 4.0s (0.76/s)
# File:ccc.md. Processing done in 3.98
# on 1: <alive_progress.core.progress.__AliveBarHandle object at 0x14ca28be0>
# Processing BS.txt |████████████████████████████████████████| 3/3 [100%] in 4.2s (0.71/s)
# File:BS.txt. Processing done in 4.25
# Processing files complete....
#
#
#
#
#
# [[{'path': '/Users/admin/Desktop/sample_data/12222_777.docx', 'file_name': 'math_incomplete_equation', 'folder_name': 'math'}, {'path': '/Users/admin/Desktop/sample_data/paper_1col.pdf', 'file_name': 'string_theory_fundamentals', 'folder_name': 'String theory'}, {'path': '/Users/admin/Desktop/sample_data/go_bruin.pptx', 'file_name': 'economy_environment_safety', 'folder_name': 'Data Visualizations'}, {'path': '/Users/admin/Desktop/sample_data/sub_dir1/1111_63.csv', 'file_name': 'Ford_Vehicle_Data', 'folder_name': 'Ford Data'}, {'path': '/Users/admin/Desktop/sample_data/text_files/ccc.md', 'file_name': 'chicago_romantic_getaways', 'folder_name': 'Chicago'}, {'path': '/Users/admin/Desktop/sample_data/sub_dir2/BS.txt', 'file_name': 'account_activity_summary', 'folder_name': 'account info'}]]
